# %% [markdown]
# Importações

# %%
import pandas as pd

# %%
vendas = pd.read_excel('Vendas.xlsx')
display(vendas)
# Out:
#        Código Venda       Data              ID Loja            Produto  \
# 0                 1 2019-01-01   Iguatemi Esplanada     Sapato Estampa
# 1                 1 2019-01-01   Iguatemi Esplanada           Camiseta
# 2                 1 2019-01-01   Iguatemi Esplanada      Sapato Xadrez
# 3                 2 2019-01-02       Norte Shopping            Relógio
# 4                 2 2019-01-02       Norte Shopping       Chinelo Liso
# ...             ...        ...                  ...                ...
# 93905         65012 2019-11-30  Shopping Vila Velha     Mochila Xadrez
# 93906         65013 2019-11-30    Ribeirão Shopping  Pulseira Listrado
# 93907         65013 2019-11-30    Ribeirão Shopping     Cueca Listrado
# 93908         65014 2019-11-30     Shopping Morumbi     Pulseira Linho
# 93909         65014 2019-11-30     Shopping Morumbi      Casaco Xadrez
#
#        Quantidade  Valor Unitário  Valor Final
# 0               1             358          358
# 1               2             180          360
# 2               1             368          368
# 3               3             200          600
# 4               1              71           71
# ...           ...             ...          ...
# 93905           2             283          566
# 93906           2              79          158
# 93907           3              67          201
# 93908           5             114          570
# 93909           4             259         1036
#
# [93910 rows x 7 columns]

# %%
iguatemi = vendas.loc[vendas['ID Loja'] == 'Iguatemi Esplanada']
morumbi = vendas.loc[vendas['ID Loja'] == 'Shopping Morumbi']
norte = vendas.loc[vendas['ID Loja'] == 'Norte Shopping']
ribeirao = vendas.loc[vendas['ID Loja'] == 'Ribeirão Shopping']
fortaleza = vendas.loc[vendas['ID Loja'] == 'Rio Mar Shopping Fortaleza']
bourbon = vendas.loc[vendas['ID Loja'] == 'Bourbon Shopping SP']
uberlandia = vendas.loc[vendas['ID Loja'] == 'Center Shopping Uberlândia']
campinas = vendas.loc[vendas['ID Loja'] == 'Iguatemi Campinas']

# %%
iguatemi.drop(["ID Loja"], axis=1, inplace=True)
display(iguatemi)
# Out:
# C:\Users\Robso\AppData\Local\Temp\ipykernel_7220\3158247264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iguatemi.drop(["ID Loja"], axis=1, inplace=True)
#        Código Venda       Data                 Produto  Quantidade  \
# 0                 1 2019-01-01          Sapato Estampa           1
# 1                 1 2019-01-01                Camiseta           2
# 2                 1 2019-01-01           Sapato Xadrez           1
# 26               21 2019-01-02  Camisa Gola V Listrado           2
# 44               34 2019-01-02         Sapato Listrado           1
# ...             ...        ...                     ...         ...
# 93745         64908 2019-11-30                    Meia           4
# 93776         64928 2019-11-30            Tênis Xadrez           3
# 93880         64993 2019-11-30            Bermuda Liso           2
# 93881         64993 2019-11-30          Chinelo Xadrez           1
# 93882         64993 2019-11-30              Cinto Liso           1
#
#        Valor Unitário  Valor Final
# 0                 358          358
# 1                 180          360
# 2                 368          368
# 26                116          232
# 44                363          363
# ...               ...          ...
# 93745              30          120
# 93776             259          777
# 93880             157          314
# 93881              66           66
# 93882             209          209
#
# [3722 rows x 6 columns]

# %%
with pd.ExcelWriter("Iguatemi Esplanada.xlsx", mode="w", engine="openpyxl") as writer:
    iguatemi.to_excel(writer) 
with pd.ExcelWriter("Shopping Morumbi.xlsx", mode="w", engine="openpyxl") as writer:
    morumbi.to_excel(writer)
