# %% [markdown]
# ### importando pandas

# %%
import pandas as pd

# %% [markdown]
# ###Criar e entender dataframe
# dataframe = tabela

# %%
#exemploDataframe = pd.DataFrame()

cadastro = {
    'Nome': ['Eliseu', 'Alberto'],
    'Idade': [23, 34],
    
}

cadastro_df = pd.DataFrame(cadastro)

# %% [markdown]
# ### como visualizar
# + Print
# + Display

# %%
display(cadastro_df)
# Out:
#       Nome  Idade
# 0   Eliseu     23
# 1  Alberto     34

# %% [markdown]
# ### importando tabela excel

# %%
Tabela_cadastro = pd.read_excel('Cadastro.xlsx')
display(Tabela_cadastro)
# Out:
#          nome  idade                   email     telefone  \
# 0   Alexandre     10           ale@gmail.com  21999999999
# 1      Bianca     35          bibi@gmail.com  21999999999
# 2     Juliana     55            ju@gmail.com  21999999999
# 3       Abreu     80         abreu@gmail.com  21999999999
# 4       Sodre     75         sodre@gmail.com  21999999999
# 5     Matheus     40          math@gmail.com  21999999999
# 6   Cleusiane     35          cleu@gmail.com  21999999999
# 7   Manuellen     38          manu@gmail.com  21999999999
# 8     Monique     24         nique@gmail.com  21999999999
# 9      Allana      8       laninha@gmail.com  21999999999
# 10       Jose     80          zeze@gmail.com  21999999999
# 11     Bianca     35  bibibeiramar@gmail.com  21999999999
#
#                 endereco
# 0                    NaN
# 1   Duque de Caxias - RJ
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5           Recreio - RJ
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9       Sao Goncalo - RJ
# 10                   NaN
# 11                   NaN

# %% [markdown]
# ###visualizar em ordenação
#
# -head
# -shape
# -describe

# %%
display(Tabela_cadastro.head(4))
# Out:
#         nome  idade            email     telefone              endereco
# 0  Alexandre     10    ale@gmail.com  21999999999                   NaN
# 1     Bianca     35   bibi@gmail.com  21999999999  Duque de Caxias - RJ
# 2    Juliana     55     ju@gmail.com  21999999999                   NaN
# 3      Abreu     80  abreu@gmail.com  21999999999                   NaN

# %%
print(Tabela_cadastro.shape)
# Out:
# (12, 5)

# %%
display(Tabela_cadastro.describe())
# Out:
#            idade      telefone
# count  12.000000  1.200000e+01
# mean   42.916667  2.200000e+10
# std    24.875904  0.000000e+00
# min     8.000000  2.200000e+10
# 25%    32.250000  2.200000e+10
# 50%    36.500000  2.200000e+10
# 75%    60.000000  2.200000e+10
# max    80.000000  2.200000e+10

# %% [markdown]
# ###Consulta especifica na tabela

# %%
nome = Tabela_cadastro['nome']
display(nome)
# Out:
# 0     Alexandre
# 1        Bianca
# 2       Juliana
# 3         Abreu
# 4         Sodre
# 5       Matheus
# 6     Cleusiane
# 7     Manuellen
# 8       Monique
# 9        Allana
# 10         Jose
# 11       Bianca
# Name: nome, dtype: object

# %%
nome_idade = Tabela_cadastro[['nome','idade']]
display(nome_idade)
# Out:
#          nome  idade
# 0   Alexandre     10
# 1      Bianca     35
# 2     Juliana     55
# 3       Abreu     80
# 4       Sodre     75
# 5     Matheus     40
# 6   Cleusiane     35
# 7   Manuellen     38
# 8     Monique     24
# 9      Allana      8
# 10       Jose     80
# 11     Bianca     35

# %% [markdown]
# ### conhecendo metodo .loc
# - busca 1 linha de acordo com alguma condição especifica
# - linhas e colunas especificas
# - valor especifico

# %%
display(Tabela_cadastro.loc[0 : 4])
# Out:
#         nome  idade            email     telefone              endereco
# 0  Alexandre     10    ale@gmail.com  21999999999                   NaN
# 1     Bianca     35   bibi@gmail.com  21999999999  Duque de Caxias - RJ
# 2    Juliana     55     ju@gmail.com  21999999999                   NaN
# 3      Abreu     80  abreu@gmail.com  21999999999                   NaN
# 4      Sodre     75  sodre@gmail.com  21999999999                   NaN

# %%
display(Tabela_cadastro.loc[Tabela_cadastro['nome' ] == 'Bianca'])
# Out:
#       nome  idade                   email     telefone              endereco
# 1   Bianca     35          bibi@gmail.com  21999999999  Duque de Caxias - RJ
# 11  Bianca     35  bibibeiramar@gmail.com  21999999999                   NaN

# %%
dadosespecificos = Tabela_cadastro.loc[Tabela_cadastro['nome'] == 'Bianca',['nome','idade','telefone']]
display(dadosespecificos)
# Out:
#       nome  idade     telefone
# 1   Bianca     35  21999999999
# 11  Bianca     35  21999999999

# %%
print(Tabela_cadastro.loc[1, "telefone"])
# Out:
# 21999999999

# %% [markdown]
# Adicionar nova coluna
#
# - abrir nova coluna
# - nova coluna

# %%
Tabela_cadastro['endereco'] = 'Rua ' + Tabela_cadastro['endereco']
display(Tabela_cadastro)
# Out:
#          nome  idade                   email     telefone  \
# 0   Alexandre     10           ale@gmail.com  21999999999
# 1      Bianca     35          bibi@gmail.com  21999999999
# 2     Juliana     55            ju@gmail.com  21999999999
# 3       Abreu     80         abreu@gmail.com  21999999999
# 4       Sodre     75         sodre@gmail.com  21999999999
# 5     Matheus     40          math@gmail.com  21999999999
# 6   Cleusiane     35          cleu@gmail.com  21999999999
# 7   Manuellen     38          manu@gmail.com  21999999999
# 8     Monique     24         nique@gmail.com  21999999999
# 9      Allana      8       laninha@gmail.com  21999999999
# 10       Jose     80          zeze@gmail.com  21999999999
# 11     Bianca     35  bibibeiramar@gmail.com  21999999999
#
#                     endereco
# 0                        NaN
# 1   Rua Duque de Caxias - RJ
# 2                        NaN
# 3                        NaN
# 4                        NaN
# 5           Rua Recreio - RJ
# 6                        NaN
# 7                        NaN
# 8                        NaN
# 9       Rua Sao Goncalo - RJ
# 10                       NaN
# 11                       NaN

# %%
Tabela_cadastro.loc[: , 'numero'] = Tabela_cadastro['idade']
display(Tabela_cadastro)
# Out:
#          nome  idade                   email     telefone  \
# 0   Alexandre     10           ale@gmail.com  21999999999
# 1      Bianca     35          bibi@gmail.com  21999999999
# 2     Juliana     55            ju@gmail.com  21999999999
# 3       Abreu     80         abreu@gmail.com  21999999999
# 4       Sodre     75         sodre@gmail.com  21999999999
# 5     Matheus     40          math@gmail.com  21999999999
# 6   Cleusiane     35          cleu@gmail.com  21999999999
# 7   Manuellen     38          manu@gmail.com  21999999999
# 8     Monique     24         nique@gmail.com  21999999999
# 9      Allana      8       laninha@gmail.com  21999999999
# 10       Jose     80          zeze@gmail.com  21999999999
# 11     Bianca     35  bibibeiramar@gmail.com  21999999999
#
#                     endereco  numero
# 0                        NaN      10
# 1   Rua Duque de Caxias - RJ      35
# 2                        NaN      55
# 3                        NaN      80
# 4                        NaN      75
# 5           Rua Recreio - RJ      40
# 6                        NaN      35
# 7                        NaN      38
# 8                        NaN      24
# 9       Rua Sao Goncalo - RJ       8
# 10                       NaN      80
# 11                       NaN      35

# %% [markdown]
# Metodo .drop() para excluir

# %%
vendas_df = pd.read_excel('vendas.xlsx')
display(vendas_df)

vendas_df = vendas_df.drop('data',axis=1)
display(vendas_df)
# Out:
#         data          produto  preco                        loja
# 0 2023-02-28          amedoin   10.0         americanas - Marica
# 1        NaT              NaN    NaN  americanas - Norte Shoping
# 2 2023-03-30        fandangos   55.0        Casas Bahia - Marica
# 3 2023-04-25  papel higienico    NaN       Casa e Video - Marica
# 4        NaT              NaN   80.0              Nalin - Marica
#            produto  preco                        loja
# 0          amedoin   10.0         americanas - Marica
# 1              NaN    NaN  americanas - Norte Shoping
# 2        fandangos   55.0        Casas Bahia - Marica
# 3  papel higienico    NaN       Casa e Video - Marica
# 4              NaN   80.0              Nalin - Marica

# %% [markdown]
# Tratamento de lishas e colunas vazias
# vendas_df = vendas_df.dropna()
# display(vendas_df)
#
# preencher valor vazio
# vendas_df['preco'] = vendas_df['preco'].fillna()

# %%
 
#vendas_df = vendas_df.dropna()
#display(vendas_df)

# %%
#vendas_df['preco'] = vendas_df['preco'].fillna(10)
#display(vendas_df)

# %%
vendas_df[ 'preco'] = vendas_df['preco'].fillna(vendas_df['preco'].mean())
display(vendas_df)
# Out:
#            produto      preco                        loja
# 0          amedoin  10.000000         americanas - Marica
# 1              NaN  48.333333  americanas - Norte Shoping
# 2        fandangos  55.000000        Casas Bahia - Marica
# 3  papel higienico  48.333333       Casa e Video - Marica
# 4              NaN  80.000000              Nalin - Marica

# %% [markdown]
# Utilizando o parametro ffill() para ajustar tabelas

# %%
vendas_df = pd.read_excel('vendas.xlsx')
display(vendas_df)

vendas_df = vendas_df.ffill()
display(vendas_df)
# Out:
#         data          produto  preco                        loja
# 0 2023-02-28          amedoin   10.0         americanas - Marica
# 1        NaT              NaN    NaN  americanas - Norte Shoping
# 2 2023-03-30        fandangos   55.0        Casas Bahia - Marica
# 3 2023-04-25  papel higienico    NaN       Casa e Video - Marica
# 4        NaT              NaN   80.0              Nalin - Marica
#         data          produto  preco                        loja
# 0 2023-02-28          amedoin   10.0         americanas - Marica
# 1 2023-02-28          amedoin   10.0  americanas - Norte Shoping
# 2 2023-03-30        fandangos   55.0        Casas Bahia - Marica
# 3 2023-04-25  papel higienico   55.0       Casa e Video - Marica
# 4 2023-04-25  papel higienico   80.0              Nalin - Marica

# %% [markdown]
# ###Contar Valores da tabela
# - value_counts()
# - groupby()

# %%
contador = vendas_df['produto'].value_counts()
display(contador)
# Out:
# amedoin            2
# papel higienico    2
# fandangos          1
# Name: produto, dtype: int64

# %%
faturamento_produtos = vendas_df[['produto','preço']].groupby('produto').sum()
display(vendas_df)
display(faturamento_produtos)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 faturamento_produtos = vendas_df[['produto','preço']].groupby('produto').sum()
#       2 display(vendas_df)
#       3 display(faturamento_produtos)
#
# File c:\Users\Robso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\Robso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File c:\Users\Robso\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['preço'] not in index"
